# %%
from datetime import datetime
import urllib.request
import time
from subprocess import call
import sys
import os

retry_time = 45


# save_path = ""

# %%
def get_raw_data(data_path, hdfs_path):
    print(data_path)
    start = time.clock()
    query = "http://export.arxiv.org/oai2?verb=ListRecords&metadataPrefix=oai_dc"
    print("request: %s" % (query))
    request = urllib.request.Request(query)
    response = urllib.request.urlopen(request).read().decode('utf-8')
    rawfile = open(data_path+'papers_0.xml', 'w')
    rawfile.write(response)
    rawfile.close()

    save_to_hdfs(data_path+'papers_0.xml', hdfs_path)

    end = time.clock()
    print("takes: %f s" % (end - start))

    pos_start = response.rfind('<resumptionToken')
    pos_end = response.rfind('</resumptionToken')
    if pos_end > 0 and pos_end > pos_start:
        pos = response.rfind('>', pos_start, pos_end)
        resume_token = response[pos + 1:pos_end]
        print("request_resume: %s" % (resume_token))
        get_resume(resume_token, data_path, hdfs_path)

# %%
def get_resume(token, data_path, hdfs_path):
    repeat = 0
    time.sleep(retry_time)
    start = time.clock()
    filen = data_path + 'papers_%s.xml' % (token.replace('|', '_'))
    rawfile = open(filen, 'w')
    try:
        query = "http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=%s" % (token)
        request = urllib.request.Request(query)
        response = urllib.request.urlopen(request).read().decode('utf-8')
        rawfile.write(response)
        rawfile.close()
        save_to_hdfs(filen, hdfs_path)

        end = time.clock()
        print("takes: %f s" % (end - start))

        pos_start = response.rfind('<resumptionToken')
        pos_end = response.rfind('</resumptionToken')
        if pos_end > 0 and pos_end > pos_start and repeat < 20:
            pos = response.rfind('>', pos_start, pos_end)
            resume_token = response[pos + 1:pos_end]
            print("request_resume: %s" % (resume_token))
            get_resume(resume_token, data_path, hdfs_path)
            repeat += 1
    except Exception as err:
        print(err)
        print("retry resume_token: %s" % (token))
        time.sleep(30)
        get_resume(token)

# %%
def save_to_hdfs(filename, hdfs_path):
    print(">>>>>>>", hdfs_path)
    file = os.path.join(hdfs_path, filename)
    try:
        out = call("hdfs dfs -test -e %s" % (file), shell=True)
        if out == 0:
            call("hdfs dfs -rm %s" % (file), shell=True)
            print("file %s exists, delete old one" % (file))
        call(['hdfs', 'dfs', '-put', filename, hdfs_path])
        print("send %s to hdfs" % (filename))
    except Exception as e:
        print("save %s to hdfs failed" % (filename))

# %%
data_path = '/home/ananth/airflow/arxiv/'
hdfs_path = '/user/ananth/arxiv/'

# %%
get_raw_data(data_path, hdfs_path)
# Out:
# /home/ananth/airflow/arxiv/
# request: http://export.arxiv.org/oai2?verb=ListRecords&metadataPrefix=oai_dc
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_0.xml to hdfs
# takes: 0.058562 s
# request_resume: 3403458|1001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_1001.xml to hdfs
# takes: 0.060318 s
# request_resume: 3403458|2001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_2001.xml to hdfs
# takes: 0.059626 s
# request_resume: 3403458|3001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_3001.xml to hdfs
# takes: 0.058961 s
# request_resume: 3403458|4001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_4001.xml to hdfs
# takes: 0.060755 s
# request_resume: 3403458|5001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_5001.xml to hdfs
# takes: 0.059453 s
# request_resume: 3403458|6001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_6001.xml to hdfs
# takes: 0.059718 s
# request_resume: 3403458|7001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_7001.xml to hdfs
# takes: 0.062180 s
# request_resume: 3403458|8001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_8001.xml to hdfs
# takes: 0.053013 s
# request_resume: 3403458|9001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_9001.xml to hdfs
# takes: 0.062288 s
# request_resume: 3403458|10001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_10001.xml to hdfs
# takes: 0.057014 s
# request_resume: 3403458|11001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_11001.xml to hdfs
# takes: 0.056416 s
# request_resume: 3403458|12001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_12001.xml to hdfs
# takes: 0.059414 s
# request_resume: 3403458|13001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_13001.xml to hdfs
# takes: 0.058663 s
# request_resume: 3403458|14001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_14001.xml to hdfs
# takes: 0.058767 s
# request_resume: 3403458|15001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_15001.xml to hdfs
# takes: 0.060365 s
# request_resume: 3403458|16001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_16001.xml to hdfs
# takes: 0.062880 s
# request_resume: 3403458|17001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_17001.xml to hdfs
# takes: 0.060866 s
# request_resume: 3403458|18001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_18001.xml to hdfs
# takes: 0.062271 s
# request_resume: 3403458|19001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_19001.xml to hdfs
# takes: 0.062063 s
# request_resume: 3403458|20001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_20001.xml to hdfs
# takes: 0.054367 s
# request_resume: 3403458|21001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_21001.xml to hdfs
# takes: 0.052830 s
# request_resume: 3403458|22001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_22001.xml to hdfs
# takes: 0.059666 s
# request_resume: 3403458|23001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_23001.xml to hdfs
# takes: 0.066405 s
# request_resume: 3403458|24001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_24001.xml to hdfs
# takes: 0.061192 s
# request_resume: 3403458|25001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_25001.xml to hdfs
# takes: 0.061352 s
# request_resume: 3403458|26001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_26001.xml to hdfs
# takes: 0.063813 s
# request_resume: 3403458|27001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_27001.xml to hdfs
# takes: 0.061381 s
# request_resume: 3403458|28001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_28001.xml to hdfs
# takes: 0.057371 s
# request_resume: 3403458|29001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_29001.xml to hdfs
# takes: 0.058251 s
# request_resume: 3403458|30001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_30001.xml to hdfs
# takes: 0.065998 s
# request_resume: 3403458|31001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_31001.xml to hdfs
# takes: 0.059274 s
# request_resume: 3403458|32001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_32001.xml to hdfs
# takes: 0.059740 s
# request_resume: 3403458|33001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_33001.xml to hdfs
# takes: 0.051989 s
# request_resume: 3403458|34001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_34001.xml to hdfs
# takes: 0.060759 s
# request_resume: 3403458|35001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_35001.xml to hdfs
# takes: 0.066388 s
# request_resume: 3403458|36001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_36001.xml to hdfs
# takes: 0.061364 s
# request_resume: 3403458|37001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_37001.xml to hdfs
# takes: 0.058215 s
# request_resume: 3403458|38001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_38001.xml to hdfs
# takes: 0.054052 s
# request_resume: 3403458|39001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_39001.xml to hdfs
# takes: 0.061780 s
# request_resume: 3403458|40001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_40001.xml to hdfs
# takes: 0.063256 s
# request_resume: 3403458|41001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_41001.xml to hdfs
# takes: 0.055948 s
# request_resume: 3403458|42001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_42001.xml to hdfs
# takes: 0.055970 s
# request_resume: 3403458|43001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_43001.xml to hdfs
# takes: 0.063710 s
# request_resume: 3403458|44001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_44001.xml to hdfs
# takes: 0.058913 s
# request_resume: 3403458|45001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_45001.xml to hdfs
# takes: 0.073381 s
# request_resume: 3403458|46001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_46001.xml to hdfs
# takes: 0.063934 s
# request_resume: 3403458|47001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_47001.xml to hdfs
# takes: 0.064809 s
# request_resume: 3403458|48001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_48001.xml to hdfs
# takes: 0.062704 s
# request_resume: 3403458|49001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_49001.xml to hdfs
# takes: 0.061873 s
# request_resume: 3403458|50001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_50001.xml to hdfs
# takes: 0.063960 s
# request_resume: 3403458|51001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_51001.xml to hdfs
# takes: 0.065265 s
# request_resume: 3403458|52001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_52001.xml to hdfs
# takes: 0.065444 s
# request_resume: 3403458|53001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_53001.xml to hdfs
# takes: 0.057395 s
# request_resume: 3403458|54001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_54001.xml to hdfs
# takes: 0.058145 s
# request_resume: 3403458|55001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_55001.xml to hdfs
# takes: 0.068510 s
# request_resume: 3403458|56001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_56001.xml to hdfs
# takes: 0.056523 s
# request_resume: 3403458|57001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_57001.xml to hdfs
# takes: 0.060943 s
# request_resume: 3403458|58001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_58001.xml to hdfs
# takes: 0.058809 s
# request_resume: 3403458|59001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_59001.xml to hdfs
# takes: 0.065387 s
# request_resume: 3403458|60001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_60001.xml to hdfs
# takes: 0.062098 s
# request_resume: 3403458|61001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_61001.xml to hdfs
# takes: 0.066919 s
# request_resume: 3403458|62001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_62001.xml to hdfs
# takes: 0.066069 s
# request_resume: 3403458|63001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_63001.xml to hdfs
# takes: 0.061721 s
# request_resume: 3403458|64001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_64001.xml to hdfs
# takes: 0.065542 s
# request_resume: 3403458|65001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_65001.xml to hdfs
# takes: 0.063756 s
# request_resume: 3403458|66001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_66001.xml to hdfs
# takes: 0.064698 s
# request_resume: 3403458|67001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_67001.xml to hdfs
# takes: 0.058034 s
# request_resume: 3403458|68001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_68001.xml to hdfs
# takes: 0.062873 s
# request_resume: 3403458|69001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_69001.xml to hdfs
# takes: 0.065724 s
# request_resume: 3403458|70001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_70001.xml to hdfs
# takes: 0.064550 s
# request_resume: 3403458|71001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_71001.xml to hdfs
# takes: 0.066416 s
# request_resume: 3403458|72001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_72001.xml to hdfs
# takes: 0.066564 s
# request_resume: 3403458|73001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_73001.xml to hdfs
# takes: 0.068569 s
# request_resume: 3403458|74001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_74001.xml to hdfs
# takes: 0.071988 s
# request_resume: 3403458|75001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_75001.xml to hdfs
# takes: 0.068391 s
# request_resume: 3403458|76001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_76001.xml to hdfs
# takes: 0.065716 s
# request_resume: 3403458|77001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_77001.xml to hdfs
# takes: 0.068432 s
# request_resume: 3403458|78001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_78001.xml to hdfs
# takes: 0.063958 s
# request_resume: 3403458|79001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_79001.xml to hdfs
# takes: 0.066608 s
# request_resume: 3403458|80001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_80001.xml to hdfs
# takes: 0.061677 s
# request_resume: 3403458|81001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_81001.xml to hdfs
# takes: 0.064885 s
# request_resume: 3403458|82001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_82001.xml to hdfs
# takes: 0.063655 s
# request_resume: 3403458|83001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_83001.xml to hdfs
# takes: 0.065274 s
# request_resume: 3403458|84001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_84001.xml to hdfs
# takes: 0.067541 s
# request_resume: 3403458|85001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_85001.xml to hdfs
# takes: 0.069097 s
# request_resume: 3403458|86001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_86001.xml to hdfs
# takes: 0.059856 s
# request_resume: 3403458|87001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_87001.xml to hdfs
# takes: 0.067381 s
# request_resume: 3403458|88001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_88001.xml to hdfs
# takes: 0.064629 s
# request_resume: 3403458|89001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_89001.xml to hdfs
# takes: 0.066759 s
# request_resume: 3403458|90001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_90001.xml to hdfs
# takes: 0.060353 s
# request_resume: 3403458|91001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_91001.xml to hdfs
# takes: 0.065005 s
# request_resume: 3403458|92001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_92001.xml to hdfs
# takes: 0.070849 s
# request_resume: 3403458|93001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_93001.xml to hdfs
# takes: 0.067917 s
# request_resume: 3403458|94001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_94001.xml to hdfs
# takes: 0.074445 s
# request_resume: 3403458|95001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_95001.xml to hdfs
# takes: 0.068197 s
# request_resume: 3403458|96001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_96001.xml to hdfs
# takes: 0.075056 s
# request_resume: 3403458|97001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_97001.xml to hdfs
# takes: 0.064821 s
# request_resume: 3403458|98001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_98001.xml to hdfs
# takes: 0.071843 s
# request_resume: 3403458|99001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_99001.xml to hdfs
# takes: 0.068587 s
# request_resume: 3403458|100001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_100001.xml to hdfs
# takes: 0.067710 s
# request_resume: 3403458|101001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_101001.xml to hdfs
# takes: 0.074516 s
# request_resume: 3403458|102001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_102001.xml to hdfs
# takes: 0.069860 s
# request_resume: 3403458|103001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_103001.xml to hdfs
# takes: 0.082643 s
# request_resume: 3403458|104001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_104001.xml to hdfs
# takes: 0.067854 s
# request_resume: 3403458|105001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_105001.xml to hdfs
# takes: 0.064719 s
# request_resume: 3403458|106001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_106001.xml to hdfs
# takes: 0.072270 s
# request_resume: 3403458|107001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_107001.xml to hdfs
# takes: 0.071273 s
# request_resume: 3403458|108001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_108001.xml to hdfs
# takes: 0.069599 s
# request_resume: 3403458|109001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_109001.xml to hdfs
# takes: 0.069210 s
# request_resume: 3403458|110001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_110001.xml to hdfs
# takes: 0.067420 s
# request_resume: 3403458|111001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_111001.xml to hdfs
# takes: 0.074554 s
# request_resume: 3403458|112001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_112001.xml to hdfs
# takes: 0.073412 s
# request_resume: 3403458|113001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_113001.xml to hdfs
# takes: 0.062405 s
# request_resume: 3403458|114001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_114001.xml to hdfs
# takes: 0.070930 s
# request_resume: 3403458|115001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_115001.xml to hdfs
# takes: 0.071047 s
# request_resume: 3403458|116001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_116001.xml to hdfs
# takes: 0.070691 s
# request_resume: 3403458|117001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_117001.xml to hdfs
# takes: 0.069223 s
# request_resume: 3403458|118001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_118001.xml to hdfs
# takes: 0.069346 s
# request_resume: 3403458|119001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_119001.xml to hdfs
# takes: 0.070861 s
# request_resume: 3403458|120001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_120001.xml to hdfs
# takes: 0.070404 s
# request_resume: 3403458|121001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_121001.xml to hdfs
# takes: 0.064818 s
# request_resume: 3403458|122001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_122001.xml to hdfs
# takes: 0.080008 s
# request_resume: 3403458|123001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_123001.xml to hdfs
# takes: 0.071990 s
# request_resume: 3403458|124001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_124001.xml to hdfs
# takes: 0.068915 s
# request_resume: 3403458|125001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_125001.xml to hdfs
# takes: 0.066322 s
# request_resume: 3403458|126001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_126001.xml to hdfs
# takes: 0.072892 s
# request_resume: 3403458|127001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_127001.xml to hdfs
# takes: 0.068898 s
# request_resume: 3403458|128001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_128001.xml to hdfs
# takes: 0.076545 s
# request_resume: 3403458|129001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_129001.xml to hdfs
# takes: 0.070075 s
# request_resume: 3403458|130001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_130001.xml to hdfs
# takes: 0.065622 s
# request_resume: 3403458|131001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_131001.xml to hdfs
# takes: 0.064852 s
# request_resume: 3403458|132001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_132001.xml to hdfs
# takes: 0.074070 s
# request_resume: 3403458|133001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_133001.xml to hdfs
# takes: 0.065260 s
# request_resume: 3403458|134001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_134001.xml to hdfs
# takes: 0.073609 s
# request_resume: 3403458|135001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_135001.xml to hdfs
# takes: 0.074358 s
# request_resume: 3403458|136001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_136001.xml to hdfs
# takes: 0.064252 s
# request_resume: 3403458|137001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_137001.xml to hdfs
# takes: 0.072484 s
# request_resume: 3403458|138001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_138001.xml to hdfs
# takes: 0.068028 s
# request_resume: 3403458|139001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_139001.xml to hdfs
# takes: 0.069356 s
# request_resume: 3403458|140001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_140001.xml to hdfs
# takes: 0.074607 s
# request_resume: 3403458|141001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_141001.xml to hdfs
# takes: 0.073255 s
# request_resume: 3403458|142001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_142001.xml to hdfs
# takes: 0.072856 s
# request_resume: 3403458|143001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_143001.xml to hdfs
# takes: 0.072527 s
# request_resume: 3403458|144001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_144001.xml to hdfs
# takes: 0.073361 s
# request_resume: 3403458|145001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_145001.xml to hdfs
# takes: 0.073053 s
# request_resume: 3403458|146001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_146001.xml to hdfs
# takes: 0.072007 s
# request_resume: 3403458|147001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_147001.xml to hdfs
# takes: 0.066359 s
# request_resume: 3403458|148001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_148001.xml to hdfs
# takes: 0.072451 s
# request_resume: 3403458|149001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_149001.xml to hdfs
# takes: 0.077193 s
# request_resume: 3403458|150001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_150001.xml to hdfs
# takes: 0.074103 s
# request_resume: 3403458|151001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_151001.xml to hdfs
# takes: 0.067347 s
# request_resume: 3403458|152001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_152001.xml to hdfs
# takes: 0.077442 s
# request_resume: 3403458|153001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_153001.xml to hdfs
# takes: 0.078143 s
# request_resume: 3403458|154001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_154001.xml to hdfs
# takes: 0.077192 s
# request_resume: 3403458|155001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_155001.xml to hdfs
# takes: 0.074675 s
# request_resume: 3403458|156001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_156001.xml to hdfs
# takes: 0.075172 s
# request_resume: 3403458|157001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_157001.xml to hdfs
# takes: 0.080371 s
# request_resume: 3403458|158001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_158001.xml to hdfs
# takes: 0.073468 s
# request_resume: 3403458|159001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_159001.xml to hdfs
# takes: 0.078151 s
# request_resume: 3403458|160001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_160001.xml to hdfs
# takes: 0.077614 s
# request_resume: 3403458|161001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_161001.xml to hdfs
# takes: 0.073076 s
# request_resume: 3403458|162001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_162001.xml to hdfs
# takes: 0.068927 s
# request_resume: 3403458|163001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_163001.xml to hdfs
# takes: 0.075023 s
# request_resume: 3403458|164001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_164001.xml to hdfs
# takes: 0.069520 s
# request_resume: 3403458|165001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_165001.xml to hdfs
# takes: 0.068251 s
# request_resume: 3403458|166001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_166001.xml to hdfs
# takes: 0.077133 s
# request_resume: 3403458|167001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_167001.xml to hdfs
# takes: 0.071396 s
# request_resume: 3403458|168001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_168001.xml to hdfs
# takes: 0.081510 s
# request_resume: 3403458|169001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_169001.xml to hdfs
# takes: 0.068056 s
# request_resume: 3403458|170001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_170001.xml to hdfs
# takes: 0.076104 s
# request_resume: 3403458|171001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_171001.xml to hdfs
# takes: 0.068904 s
# request_resume: 3403458|172001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_172001.xml to hdfs
# takes: 0.072199 s
# request_resume: 3403458|173001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_173001.xml to hdfs
# takes: 0.078675 s
# request_resume: 3403458|174001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_174001.xml to hdfs
# takes: 0.075252 s
# request_resume: 3403458|175001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_175001.xml to hdfs
# takes: 0.073615 s
# request_resume: 3403458|176001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_176001.xml to hdfs
# takes: 0.078704 s
# request_resume: 3403458|177001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_177001.xml to hdfs
# takes: 0.075333 s
# request_resume: 3403458|178001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_178001.xml to hdfs
# takes: 0.077856 s
# request_resume: 3403458|179001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_179001.xml to hdfs
# takes: 0.083220 s
# request_resume: 3403458|180001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_180001.xml to hdfs
# takes: 0.079801 s
# request_resume: 3403458|181001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_181001.xml to hdfs
# takes: 0.076031 s
# request_resume: 3403458|182001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_182001.xml to hdfs
# takes: 0.071653 s
# request_resume: 3403458|183001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_183001.xml to hdfs
# takes: 0.077845 s
# request_resume: 3403458|184001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_184001.xml to hdfs
# takes: 0.079136 s
# request_resume: 3403458|185001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_185001.xml to hdfs
# takes: 0.080941 s
# request_resume: 3403458|186001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_186001.xml to hdfs
# takes: 0.070085 s
# request_resume: 3403458|187001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_187001.xml to hdfs
# takes: 0.070919 s
# request_resume: 3403458|188001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_188001.xml to hdfs
# takes: 0.077092 s
# request_resume: 3403458|189001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_189001.xml to hdfs
# takes: 0.083545 s
# request_resume: 3403458|190001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_190001.xml to hdfs
# takes: 0.076851 s
# request_resume: 3403458|191001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_191001.xml to hdfs
# takes: 0.081993 s
# request_resume: 3403458|192001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_192001.xml to hdfs
# takes: 0.079422 s
# request_resume: 3403458|193001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_193001.xml to hdfs
# takes: 0.080141 s
# request_resume: 3403458|194001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_194001.xml to hdfs
# takes: 0.076175 s
# request_resume: 3403458|195001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_195001.xml to hdfs
# takes: 0.079010 s
# request_resume: 3403458|196001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_196001.xml to hdfs
# takes: 0.071101 s
# request_resume: 3403458|197001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_197001.xml to hdfs
# takes: 0.069514 s
# request_resume: 3403458|198001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_198001.xml to hdfs
# takes: 0.072912 s
# request_resume: 3403458|199001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_199001.xml to hdfs
# takes: 0.075150 s
# request_resume: 3403458|200001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_200001.xml to hdfs
# takes: 0.075345 s
# request_resume: 3403458|201001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_201001.xml to hdfs
# takes: 0.078040 s
# request_resume: 3403458|202001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_202001.xml to hdfs
# takes: 0.077226 s
# request_resume: 3403458|203001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_203001.xml to hdfs
# takes: 0.075478 s
# request_resume: 3403458|204001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_204001.xml to hdfs
# takes: 0.077717 s
# request_resume: 3403458|205001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_205001.xml to hdfs
# takes: 0.074095 s
# request_resume: 3403458|206001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_206001.xml to hdfs
# takes: 0.075749 s
# request_resume: 3403458|207001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_207001.xml to hdfs
# takes: 0.077994 s
# request_resume: 3403458|208001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_208001.xml to hdfs
# takes: 0.079313 s
# request_resume: 3403458|209001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_209001.xml to hdfs
# takes: 0.073787 s
# request_resume: 3403458|210001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_210001.xml to hdfs
# takes: 0.076118 s
# request_resume: 3403458|211001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_211001.xml to hdfs
# takes: 0.080168 s
# request_resume: 3403458|212001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_212001.xml to hdfs
# takes: 0.075403 s
# request_resume: 3403458|213001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_213001.xml to hdfs
# takes: 0.078629 s
# request_resume: 3403458|214001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_214001.xml to hdfs
# takes: 0.078906 s
# request_resume: 3403458|215001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_215001.xml to hdfs
# takes: 0.081670 s
# request_resume: 3403458|216001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_216001.xml to hdfs
# takes: 0.080793 s
# request_resume: 3403458|217001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_217001.xml to hdfs
# takes: 0.080464 s
# request_resume: 3403458|218001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_218001.xml to hdfs
# takes: 0.078898 s
# request_resume: 3403458|219001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_219001.xml to hdfs
# takes: 0.077457 s
# request_resume: 3403458|220001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_220001.xml to hdfs
# takes: 0.081111 s
# request_resume: 3403458|221001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_221001.xml to hdfs
# takes: 0.073352 s
# request_resume: 3403458|222001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_222001.xml to hdfs
# takes: 0.071946 s
# request_resume: 3403458|223001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_223001.xml to hdfs
# takes: 0.080144 s
# request_resume: 3403458|224001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_224001.xml to hdfs
# takes: 0.077751 s
# request_resume: 3403458|225001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_225001.xml to hdfs
# takes: 0.083333 s
# request_resume: 3403458|226001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_226001.xml to hdfs
# takes: 0.074604 s
# request_resume: 3403458|227001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_227001.xml to hdfs
# takes: 0.078441 s
# request_resume: 3403458|228001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_228001.xml to hdfs
# takes: 0.079079 s
# request_resume: 3403458|229001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_229001.xml to hdfs
# takes: 0.081023 s
# request_resume: 3403458|230001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_230001.xml to hdfs
# takes: 0.073665 s
# request_resume: 3403458|231001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_231001.xml to hdfs
# takes: 0.080973 s
# request_resume: 3403458|232001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_232001.xml to hdfs
# takes: 0.075768 s
# request_resume: 3403458|233001
# >>>>>>> /user/ananth/arxiv/
# send /home/ananth/airflow/arxiv/papers_3403458_233001.xml to hdfs
# takes: 0.075802 s
# request_resume: 3403458|234001

# %%
import findspark
findspark.init('/opt/cloudera/parcels/SPARK2-2.3.0.cloudera3-1.cdh5.13.3.p0.458809/lib/spark2/')

import xml.etree.ElementTree as ET

import os

from pyspark.sql import SparkSession

xmlpath = '/user/ananth/arxiv'
parpath = '/user/ananth/arxiv/parquet/'
spark = SparkSession.builder.getOrCreate()
sc = spark.sparkContext
# Out:
# /opt/cloudera/parcels/SPARK2-2.3.0.cloudera3-1.cdh5.13.3.p0.458809/lib/spark2/python/pyspark/sql/session.py:360: UserWarning: Using RDD of dict to inferSchema is deprecated. Use pyspark.sql.Row instead
#   warnings.warn("Using RDD of dict to inferSchema is deprecated. "

# %%
def process(file):
    """
    Process an Arvix XML file and generates a dictionary with its contents
    :param file: XML file
    :return: list of dictionaries with contents
    """
    prefix = "{http://www.openarchives.org/OAI/2.0/}"
    prefix2 = "{http://purl.org/dc/elements/1.1/}"
    
    content = file[1].decode("utf-8")
    root = ET.fromstring(content)
    records = root.find(prefix + "ListRecords")
    data = []
    try:
        for record in records.findall(prefix + "record"):
            identifier = record[0].text
            datastamp = record[1].text
            subjects = []
            for subject in record[0].findall(prefix + "setSpec"):
                subjects.append(subject.text)
            if len(subjects) == 0:
                subjects.append("none")

            dc = record[1][0]
            title = dc[0].text
            authors = []
            for author in dc.findall(prefix2 + "creator"):
                authors.append(author.text)
                if len(authors) == 0:
                    authors.append("none")
            abstract = dc.find(prefix2 + "description").text

            d = {"id": identifier, "datastamp": datastamp, "title": title, "subjects": subjects, "authors": authors,
                 "abstract": abstract}
            data.append(d)
        return data
    except:
        return data

# %%
filep = os.path.join(xmlpath, "papers_*.xml")
xmlfiles = sc.binaryFiles(filep)
xmldf = xmlfiles.flatMap(process).toDF()
# Out:
# /opt/cloudera/parcels/SPARK2-2.3.0.cloudera3-1.cdh5.13.3.p0.458809/lib/spark2/python/pyspark/sql/session.py:360: UserWarning: Using RDD of dict to inferSchema is deprecated. Use pyspark.sql.Row instead
#   warnings.warn("Using RDD of dict to inferSchema is deprecated. "

# %%
xmldf.count()
# Out:
# 568316

# %%
parpath = '/user/ananth/arxiv/parquet/'
xmldf.write.parquet(parpath)

# %%
# parpath = '/user/ananth/arxiv/parquet/arxiv.parquet'
# xmldf.write.parquet(parpath)
